# %% [markdown]
# <a href="https://colab.research.google.com/github/paulIruaRosero/Paul-Irua-Rosero-se-ales-y-sistemas/blob/main/C%C3%B3digo_parcial_2_de_se%C3%B1ales_y_sistemas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# grafica de la función del primer ejercicio:
# $$
# x(t) = \ |Asin(2πFot)|^{2}\\
# $$
# observese que se ingresó un valor arbitrario de A = 1 para darle forma a la función y para la frecuencia fundamental Fo = 2π

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 1 #valor arbitrario de la amplitud de la señal asignada por el usuario para observar presentación en la simulación
Fo = 2*np.pi #frecuencia fundamental de la señal

ti = -1/(2*Fo) #tiempo inicial
tf = 1/(2*Fo) #tiempo final
wo = 2*np.pi/(tf-ti) #frecuencia angular
Fo = wo/2*np.pi #frecuencia fundamental
print('wo=',wo)
print('Fo=',Fo)
Fs = 10*Fo #frecuencia muestreo -> debe respetar Nyquist Fs >= 2 Fo
tv = np.arange(ti,tf,1/Fs) #vector de tiempo

x = abs(A*np.sin(2*np.pi*Fo*tv))**2 #señal de entrada
plt.plot(tv,x) #gráfica de la señal
plt.xlabel('tiempo [s]')
plt.ylabel('')
plt.show()
# Out:
# wo= 39.47841760435743
# Fo= 62.01255336059963

# %% [markdown]
# vamos a realizar la simulación del segundo punto del parcial
#
# Solución:

# %%
ti = -1/(2*Fo) #tiempo inicial
tf = 1/(2*Fo) #tiempo final
wo = 2*np.pi/(tf-ti) #frecuencia angular
Fo = wo/2*np.pi #frecuencia fundamental

Fs = 50*Fo #frecuencia muestreo -> debe respetar Nyquist Fs >= 2 Fo
tv = np.arange(ti,tf,1/Fs) #vector de tiempo



T = tf - ti #intervalo de interés
N = 50 #número armonicos a simular
wo = 2*np.pi/T # frecuencia fundamental
# definir bases
phin = np.zeros((len(tv),2*N+1),dtype=np.complex_)#crear matriz para guardar bases
for n in range(-N,N+1,1):
    phin[:,n+N] = np.exp(1j*n*wo*tv)#base de fourier en el intervalo de interés

# graficar bases
from ipywidgets import interact,IntSlider

def pltbase(n=1):
    plt.plot(tv,np.real(phin[:,int(n+N)]),label="Re{Øn(t)}")
    plt.xlabel("t[s]",fontsize = 14)
    plt.ylabel("Øn(t)",fontsize = 14)
    plt.plot(tv,np.imag(phin[:,int(n+N)]),label="Im{Øn(t)}")
    plt.grid()
    plt.legend()
    plt.show()
    return
interact(pltbase,n=(-N,N,1))

#calcular espectro -> cambiar según la señal estudiada
cn = np.zeros(2*N+1,dtype=np.complex_)
nv = np.linspace(-N, N, 2*N+1) #vector armónicos
cn[N] = A**2 / 2 # nivel dc C_0
cn[N-2] = -A**2/4 #armónico -2
cn[N+2] = -A**2/4 #armónico +2
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=50, min=-50), Output()), _dom_classes=('widget-i…

# %%
#graficar espectro
fig = plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.stem(nv, np.real(cn), 'r')
plt.xlabel(r'nwo[rad/s]',fontsize = 14)
plt.ylabel(r'Re{Cn}',fontsize = 14)
plt.axis('tight')
plt.grid()


plt.subplot(2,2,2)
plt.stem(nv, np.imag(cn), 'r')
plt.xlabel(r'nwo[rad/s]',fontsize = 14)
plt.ylabel(r'Im{Cn}',fontsize = 14)
plt.axis('tight')
plt.grid()


plt.subplot(2,2,3)
plt.stem(nv, abs(cn), 'r')#magnitud del espectro
plt.xlabel(r'nwo[rad/s]',fontsize = 14)
plt.ylabel(r'|Cn|',fontsize = 14)
plt.axis('tight')
plt.grid()

plt.subplot(2,2,4)
plt.stem(nv, np.angle(cn), 'r')#fase del espectro
plt.xlabel(r'nwo[rad/s]',fontsize = 14)
plt.ylabel(r'Cn',fontsize = 14)
plt.axis('tight')
plt.grid()

fig.tight_layout()

# %%
Px = (3*A**4)/2 # potencia señal x(t)
def pltest(Na=1):
    ind = range(N-Na,N+Na+1)
    er = 1- np.sum(abs(cn[ind])**2)/Px
    #señal reconstruida
    xe = phin[:,ind].dot(cn[ind] ) # dot calcula el producto entre vectores
    plt.plot(tv,xe,color='b',label='Xe(t)') # señal estimada o filtrada
    plt.plot(tv,x,color='r',label='x(t)') #señal original
    plt.title('E_r=%.2f[%%]' % (100*er),fontsize=16)
    plt.xlabel('t[s]')
    plt.ylabel('x(t)')
    plt.grid()
    plt.legend()
    plt.show()
    return

# %%
# !pip install yt-dlp

link = "https://www.youtube.com/watch?v=nyuo9-OjNNg"
# !yt-dlp --extract-audio --audio-format mp3 -o "audio.%(ext)s" {link}
# Out:
# ...
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nyuo9-OjNNg
# [youtube] nyuo9-OjNNg: Downloading webpage
# [youtube] nyuo9-OjNNg: Downloading ios player API JSON
# [youtube] nyuo9-OjNNg: Downloading web creator player API JSON
# [youtube] nyuo9-OjNNg: Downloading m3u8 information
# [info] nyuo9-OjNNg: Downloading 1 format(s): 251
# [download] audio.mp3 has already been downloaded
# [ExtractAudio] Not converting audio audio.mp3; file is already in target format mp3

# %%
#convertir a .wav con ffmpeg para extraer audio en python
# !ffmpeg -i audio.mp3 output.wav
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
#instalar soundfile para cargar .wav
# !pip install soundfile

# %%
import soundfile as sf # para instalar pip install soundfile
from IPython.display import Audio #librería para reproducir audio
#leer archivo wav
nombre_out = "output.wav"
xa, fs = sf.read(nombre_out)
# read speech signal from file
print('Frecuencia de muestreo %.2f[Hz]\naudio %s' % (fs,nombre_out))
# Out:
# Frecuencia de muestreo 48000.00[Hz]
# audio output.wav

# %%
xpro = xa.copy() #copiar archivos para procesar
#leer 5 segundos de la canción
ti = 20 #tiempo incio a procesar seg
tf = 25 #tiempo final a procesar seg
m = xpro[int(ti*fs):int((tf*fs)),0] #señal mensaje en primer canal

# %%
#repoducir fragmento original #señal mensaje
Audio(m,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Vamos a realizar la simulación del tercer punto del parcial:
#
# canción escogida para la simulación: The Black Eyed Peas - I Gotta Feeling

# %% [markdown]
# solución del punto 4 del parcial:
#
# vamos a realizar un ejemplo en el cual consiste en un circuito rectificador de onda completa con 2 cargas
#
# carga resistiva: cuando tenemos una carga que es una resistencia pura, la corriente sigue la forma de la tensión, es decir las ondas de voltaje y corriente están en fase, haciendo que la distorsión armónica sea minima.
#
# carga RC en serie: cuando se añade una carga capacitiva en serie con la resistencia, se introduce una fase entre la corriente y la tensión, lo que afecta la distorsión armónica y el factor de potencia.
#
# vamos a realizar la simulación correspondiente.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft

# Parámetros generales
f = 50  # Frecuencia de la señal en Hz
T = 1/f  # Periodo
t = np.linspace(0, 2*T, 1000)  # Vector de tiempo para dos ciclos

# Función para la señal del rectificador de onda completa
def rectificador_onda_completa(t, R, C=None):
    if C is None:  # Carga puramente resistiva
        return np.abs(np.sin(2 * np.pi * f * t)) / R
    else:  # Carga RC en serie
        tau = R * C
        return np.abs(np.sin(2 * np.pi * f * t) * np.exp(-t/tau))

# Parámetros para la carga resistiva
R_resistiva = 10  # Ohmios

# Parámetros para la carga RC en serie
R_rc = 10  # Ohmios
C_rc = 1e-3  # Faradios

# Señales del rectificador
v_resistiva = rectificador_onda_completa(t, R_resistiva)
v_rc = rectificador_onda_completa(t, R_rc, C_rc)

# Graficar las señales
plt.figure(figsize=(10, 6))
plt.plot(t, v_resistiva, label='Rectificador con carga resistiva')
plt.plot(t, v_rc, label='Rectificador con carga RC en serie')
plt.xlabel('Tiempo [s]')
plt.ylabel('Voltaje [V]')
plt.title('Rectificador de Onda Completa con Diferentes Cargas')
plt.legend()
plt.show()

# Calcular la FFT para obtener armónicos
N = len(t)
V_resistiva_fft = np.abs(fft(v_resistiva)) / N
V_rc_fft = np.abs(fft(v_rc)) / N
frequencies = np.fft.fftfreq(N, t[1] - t[0])

# Graficar el espectro de frecuencias (FFT)
plt.figure(figsize=(10, 6))
plt.stem(frequencies[:N//2], V_resistiva_fft[:N//2], label='FFT Carga Resistiva', use_line_collection=True)
plt.stem(frequencies[:N//2], V_rc_fft[:N//2], label='FFT Carga RC', linefmt='r-', markerfmt='ro', use_line_collection=True)
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Magnitud')
plt.title('Espectro de Frecuencias (FFT) para Diferentes Cargas')
plt.legend()
plt.show()

# Cálculo del THD
def calcular_thd(V_fft):
    fundamental = V_fft[1]  # Componente fundamental (primer armónico)
    armonicos = np.sqrt(np.sum(V_fft[2:]**2))  # Suma de los armónicos superiores
    return armonicos / fundamental

thd_resistiva = calcular_thd(V_resistiva_fft)
thd_rc = calcular_thd(V_rc_fft)

print(f"THD para carga resistiva: {thd_resistiva:.4f}")
print(f"THD para carga RC: {thd_rc:.4f}")

# Cálculo del Factor de Potencia Distorsionado
fp_dist_resistiva = 1 / np.sqrt(1 + thd_resistiva**2)
fp_dist_rc = 1 / np.sqrt(1 + thd_rc**2)

print(f"Factor de potencia distorsionado para carga resistiva: {fp_dist_resistiva:.4f}")
print(f"Factor de potencia distorsionado para carga RC: {fp_dist_rc:.4f}")
# Out:
# <ipython-input-55-cfa047b1aab9>:47: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(frequencies[:N//2], V_resistiva_fft[:N//2], label='FFT Carga Resistiva', use_line_collection=True)
# <ipython-input-55-cfa047b1aab9>:48: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(frequencies[:N//2], V_rc_fft[:N//2], label='FFT Carga RC', linefmt='r-', markerfmt='ro', use_line_collection=True)
# THD para carga resistiva: 460.2700
# THD para carga RC: 1.8687
# Factor de potencia distorsionado para carga resistiva: 0.0022
# ...
