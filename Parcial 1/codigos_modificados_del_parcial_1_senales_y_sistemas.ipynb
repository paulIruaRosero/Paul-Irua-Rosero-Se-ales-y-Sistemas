# %% [markdown]
# <a href="https://colab.research.google.com/github/paulIruaRosero/Paul-Irua-Rosero-Se-ales-y-Sistemas/blob/main/Parcial%201/codigos_modificados_del_parcial_1_senales_y_sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Parcial 1-Señales y sistemas 2024-2

# %% [markdown]
# Cuál es la señal obtenida en tiempo discreto al utilizar un conversor análogo digital de 5 bits con frecuencia de muestreo de $5kHz$, entrada análoga de -3.3 a 3.3 [v], aplicado a la señal continua $x(t) = 0.3 \cos(1000\pi t-\pi/4) +
# 0.6 \sin(2000\pi t) + 0.1 \cos(11000\pi t-\pi)$?. Realizar la simulación del proceso de digitalización incluyendo al menos 3 ciclos de la señal $x(t)$.
#
# En caso de que la digitalización no sea apropiada, diseñe e implemente un conversor adecuado para la señal estudiada. El convesor debe permitir configurar la cantidad de bits, rango de la entrada análoga y la frecuencia de muestreo, indicándole al usuario si dicha frecuencia es apropiada o no, y graficar la señal continua, discreta y digital.

# %% [markdown]
# ##Solución

# %%
#simulación de la señal continua x(t)
print('Bienvenido señor usuario, en este programa vamos a mostrar la gráfica de la función x(t) mostrada en el ejercicio: ') #mensaje de bienvenida al usuario

import matplotlib.pyplot as plt #importamos libreria para graficos
import sympy as sym #importamos libreria para cálculo simbólico
# %matplotlib inline

def pregunta_opcion():
  respuesta = input('señor usuario, ¿le gustaría ajustar el tiempo de visualización de la señal x(t)? (si/no): ').lower()#pide respuesta y la transforma a minusculas
  if respuesta == 'si' or respuesta == 'no':
    return respuesta #si la respuesta es valida, el sistema la toma
  else:
    print('Error, solo se aceptan respuestas como si o no, por favor vuelva a correr el programa')

#llamamos a la función
opcion = pregunta_opcion()
if opcion == 'si':
  print('muy bien, vamos a realizar la acción solicitada: ')

  print('por favor ingrese el rango de tiempo que desea visualizar en la gráfica')
  x_size1 = input('desde donde: ')
  x_size2 = input('hasta donde: ')
  print('señal x(t): ')
  x1 = float(x_size1)
  x2 = float(x_size2)

  t = sym.symbols('t', real=True)#se declara la variable simbólica t como variable temporal

  #vamos a definir algunos parámetros importantes de las sub-funciones
  A1 = 0.3 #amplitud, función 1
  om1= 1000*sym.pi #velocidad angular de la funcion 1 (omega)
  A2=0.6 #amplitud, fundión 2
  om2=2000*sym.pi #velocidad angular de la funcion 2
  A3=0.1 #amplitud de la función 3
  om3=11000*sym.pi #velocidad angular de la función 3

  #operación superposición en sympy
  x = A1*sym.cos(om1*t-sym.pi/4) + A2*sym.sin(om2*t)+A3*sym.cos(om3*t-sym.pi)
  #se grafica la señal resultante

  title = r'$x(t) = 0.3 \cos(1000\pi t-\pi/4) + 0.6 \sin(2000\pi t) + 0.1 \cos(11000\pi t-\pi)$'
  p = sym.plot(x, (t, x1, x2), ylim=[-1.2, 1.2], ylabel=r'$x(t)$', title = title, line_color = 'purple'); #definimos los limites de la grafica
  #vamos a activar la visualización de cuadrícula del gráfico


elif opcion == 'no':
  print('muy bien, vamos a mostrar la gráfica con los valores de entrada pre-establecidos:')

  t = sym.symbols('t', real=True)#se declara la variable simbólica t como variable temporal

  #vamos a definir algunos parámetros importantes de las sub-funciones
  A1 = 0.3 #amplitud, función 1
  om1= 1000*sym.pi #velocidad angular de la funcion 1 (omega)
  A2=0.6 #amplitud, fundión 2
  om2=2000*sym.pi #velocidad angular de la funcion 2
  A3=0.1 #amplitud de la función 3
  om3=11000*sym.pi #velocidad angular de la función 3

  #operación superposición en sympy
  x = A1*sym.cos(om1*t-sym.pi/4) + A2*sym.sin(om2*t)+A3*sym.cos(om3*t-sym.pi)
  #se grafica la señal resultante
  title = r'$x(t) = 0.3 \cos(1000\pi t-\pi/4) + 0.6 \sin(2000\pi t) + 0.1 \cos(11000\pi t-\pi)$' #agregamos un titulo a la señal
  p = sym.plot(x, (t,-5,5), ylim=[-1.2, 1.2], ylabel=r'$x(t)$', title = title, line_color = 'purple'); #definimos los limites de la grafica
  #vamos a activar la visualización de cuadrícula del gráfico
# Out:
# Bienvenido señor usuario, en este programa vamos a mostrar la gráfica de la función x(t) mostrada en el ejercicio:
# señor usuario, ¿le gustaría ajustar el tiempo de visualización de la señal x(t)? (si/no): si
# muy bien, vamos a realizar la acción solicitada:
# por favor ingrese el rango de tiempo que desea visualizar en la gráfica
# desde donde: 0
# hasta donde: 6
# señal x(t):

# %%
# simulación de la señal discreta x[n]
import numpy as np
import matplotlib.pyplot as plt

print('Bienvenido de nuevo señor usuario, en este programa vamos a mostrar la señal x(t) discretizada bajo ciertas condiciones') #mensaje de bienvenida al usuario
print('para este ejercicio necesitamos que ingrése un valor de frecuencia de muestreo de la señal x[n]') #se explica que se necesita que ingrese un dato necesario para que el programa pueda funcionar
print('al realizar el proceso de discretización es necesario ingresar una frecuencia de muestreo mayor o igual a 11 khz para que no se presente aliasing') # se le explica al usuario el límite de la frecuencia de muestreo a ingresar

freq_muestreo1 = float(input('Por favor ingrese una frecuencia de muestreo para discretizar la señal: '))

freq_muestreo = round(freq_muestreo1)
if freq_muestreo < 11000:
  print('Error: es necesario ingresar una frecuencia de muestreo entera mayor o igual a 11000 ')
else:
  print(f'muy bien, vamos a realizar el proceso de discretización con {freq_muestreo} hz: ')

  def pregunta1():
    respuesta1 = input('señor usuario, ¿le gustaría observar el tiempo de muestreo y la cantidad de muestras capturadas? (si/no): ').lower()#pide respuesta y la transforma a minusculas
    if respuesta1 == 'si' or respuesta1 == 'no':
      return respuesta1 #si la respuesta es valida, el sistema la toma
    else:
      print('Error: solo se aceptan respuestas como si o no, por favor vuelva a correr el programa')


      #Datos señal continua x1(t)
  A1=0.3 #amplitud
  f1=500 #frecuencia
  T1=1/f1 #periodo

  #Datos señal continua x2(t)
  A2=0.6 #amplitud
  f2=1000  #frecuencia
  T2=1/f2 #periodo

  #Datos señal continua x3(t)
  A3=0.1 #amplitud
  f3=5500 #frecuencia
  T3=1/f3#periodo

  #Periodo de la señal cuasiperiodica
  T=1/500

  #Discretizar tiempo
  ti=0 #tiempo inicial
  tf=3*T #tiempo final
  Fs=int(freq_muestreo) #frecuencia de muestreo
  Ts=1/Fs #tiempo de muestreo

  #Crear vector discretizado
  tv=np.arange(ti,tf,Ts)

   #llamamos a la función
  opcion1 = pregunta1()
  if opcion1 == 'si':
    print('muy bien, vamos a realizar la acción solicitada: ')
    print(tv)
    print(tv.shape)

      #Discretizar señal
    xv=A1*np.cos((2*np.pi*f1*tv-np.pi/4))+A2*np.sin((2*np.pi*f2*tv))+A3*np.cos((2*np.pi*f3*tv-np.pi))

    #imprimir señal discretizada
    plt.stem(tv,xv)
    plt.plot(tv,xv, color = 'green')
    plt.title("señal x[t] discretizada: ")
    plt.xlabel("tiempo [seg]")
    plt.ylabel("amplitud [V]")
    plt.grid()
    plt.show()
  elif opcion1 == 'no':

    #Discretizar señal
    xv=A1*np.cos((2*np.pi*f1*tv-np.pi/4))+A2*np.sin((2*np.pi*f2*tv))+A3*np.cos((2*np.pi*f3*tv-np.pi))

    #imprimir señal discretizada
    plt.stem(tv,xv)
    plt.plot(tv,xv, color = 'green')
    plt.title("señal x[t] discretizada: ")
    plt.xlabel("tiempo [seg]")
    plt.ylabel("amplitud [V]")
    plt.grid()
    plt.show()
# Out:
# Bienvenido de nuevo señor usuario, en este programa vamos a mostrar la señal x(t) discretizada bajo ciertas condiciones
# para este ejercicio necesitamos que ingrése un valor de frecuencia de muestreo de la señal x[n]
# al realizar el proceso de discretización es necesario ingresar una frecuencia de muestreo mayor o igual a 11 khz para que no se presente aliasing
# Por favor ingrese una frecuencia de muestreo para discretizar la señal: 15000
# muy bien, vamos a realizar el proceso de discretización con 15000 hz:
# señor usuario, ¿le gustaría observar el tiempo de muestreo y la cantidad de muestras capturadas? (si/no): no

# %%
# cuantizacion y digitalización de la señal  x[n]
print('Bienvenido de nuevo señor usuario, en este ejercicio vamos a realizar el proceso de cuantización y digitalización de la señal x(t)')

import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist

print('vamos a definir el rango de entrada de la señal x(t) despues de cero y pendiente')
entrada1 = float(input('de donde: '))
entrada2 = float(input('hasta donde: '))

num_bits = int(input('Por favor ingrese la cantidad de bits para la señal digital: '))

if num_bits > 0:
    #Datos señal continua x1(t)
  A1=0.3 #amplitud
  f1=500 #frecuencia
  T1=1/f1 #periodo

  #Datos señal continua x2(t)
  A2=0.6 #amplitud
  f2=1000  #frecuencia
  T2=1/f2 #periodo

  #Datos señal continua x3(t)
  A3=0.1 #amplitud
  f3=5500 #frecuencia
  T3=1/f3#periodo

  #Periodo de la señal cuasiperiodica
  T=1/500

  #Discretizar tiempo
  ti=0 #tiempo inicial
  tf=3*T #tiempo final
  Fs=float(freq_muestreo) #frecuencia de muestreo cumpliendo Nyquist
  Ts=1/Fs #tiempo de muestreo
  #Crear vector discretizado
  tv=np.arange(ti,tf,Ts)
  print(tv)
  print(tv.shape)

  #Discretizar señal
  xv=A1*np.cos((2*np.pi*f1*tv-np.pi/4))+A2*np.sin((2*np.pi*f2*tv))+A3*np.cos((2*np.pi*f3*tv-np.pi))
  print(xv)
  print(xv.shape)
  print('señal x(t) cuantizada y digitalizada: ')

  #Cuantización de la señal

  #Acondicionar la señal (modificar amplitud)
  y_max=entrada2
  y_min=entrada1
  def modificar_amplitud (x,ymin,ymax):
  #Vamos a hallar la pendiente
    xmin=min(x) #Esta función me saca el minimo de la señal discretizada
    xmax=max(x) #Esta función me saca el maximo de la señal discretizada
    m=(ymax-ymin)/(xmax-xmin) #Aquí modificamos la pendiente para escalar la señal y que el dispositivo que trabaja de 4mA a 20mA la reciba de 4mA a 20mA
    c=ymax-m*xmax #Hallamos la c, porque la ecuación y=mx+c lo requiere y para que se mantenga la forma de la señal original
    yv=m*x+c #aqui calculamos la señal discretizada de 4mA a 20mA
    return yv

  #vamos a pasarle los datos a la función modificar_amplitud para que nos calcule la señal acondicionada (yv)
  yv= modificar_amplitud(xv,y_min,y_max)

  #número de bits y vector de cuantización
  nbits = int(num_bits)
  rmin = entrada1
  rmax = entrada2
  ve = np.linspace(rmin,rmax,2**nbits) # (rmax-rmin)/(2^#bits - 1) -> si se quiere incluir rmin y rmax

  #distancias y cero pendiente a vector cuantizacion
  d = cdist(yv.reshape(-1,1),ve.reshape(-1,1)) #se utiliza reshape(-1,1) para generar vectores columna como lo pide cdist
  d.shape
  #función cuantización punto a punto

  def my_cuantizador(yn, vq) : #yn punto a #cuantizar, vq vector de estados

    Ne = vq.shape[0] #tamaño vector de estados
    dn = cdist(yn.reshape(-1,1),vq.reshape(-1,1))#distancia yn a vector estados, reshape(-1,1) asegura vectores columna para poder utilizar cdist
    ind = np.argmin(dn) #posición distancia min
    return vq[ind]

  #recorrer vector cero y spam discretizado para cuantizar
  for i in range(yv.shape[0]):
    if i==0: #primera muestra
      yq = my_cuantizador(yv[i],ve)
    else:
      yq = np.append(yq,my_cuantizador(yv[i],ve)) #apilar datos cuantizando si i>0

  #graficar señal dsicreta
  plt.stem(tv,yv, label='ycs_dis')#cs discreta
  #estados de cuantización
  for v in ve:
    plt.plot(tv,v*np.ones(len(tv)))
    # graficar señal Digital (discreta + cuantizada)
  plt.plot(tv,yq,c='y',marker='o',label='ydig', linewidth=2)

  plt.legend()
  plt.grid()
  plt.xlabel('t[Seg]')
  plt.ylabel('Amplitud [A]')
  plt.show()
else:
  print('Error: por favor ingrese un número de bits mayor a 0, por favor vuelva a correr el programa ')
# Out:
# Bienvenido de nuevo señor usuario, en este ejercicio vamos a realizar el proceso de cuantización y digitalización de la señal x(t)
# vamos a definir el rango de entrada de la señal x(t) despues de cero y pendiente
# de donde: -3.3
# hasta donde: 3.3
# Por favor ingrese la cantidad de bits para la señal digital: 5
# [0.00000000e+00 6.66666667e-05 1.33333333e-04 2.00000000e-04
#  2.66666667e-04 3.33333333e-04 4.00000000e-04 4.66666667e-04
#  5.33333333e-04 6.00000000e-04 6.66666667e-04 7.33333333e-04
#  8.00000000e-04 8.66666667e-04 9.33333333e-04 1.00000000e-03
#  1.06666667e-03 1.13333333e-03 1.20000000e-03 1.26666667e-03
#  1.33333333e-03 1.40000000e-03 1.46666667e-03 1.53333333e-03
#  1.60000000e-03 1.66666667e-03 1.73333333e-03 1.80000000e-03
#  1.86666667e-03 1.93333333e-03 2.00000000e-03 2.06666667e-03
#  2.13333333e-03 2.20000000e-03 2.26666667e-03 2.33333333e-03
#  2.40000000e-03 2.46666667e-03 2.53333333e-03 2.60000000e-03
#  2.66666667e-03 2.73333333e-03 2.80000000e-03 2.86666667e-03
#  2.93333333e-03 3.00000000e-03 3.06666667e-03 3.13333333e-03
#  3.20000000e-03 3.26666667e-03 3.33333333e-03 3.40000000e-03
#  3.46666667e-03 3.53333333e-03 3.60000000e-03 3.66666667e-03
#  3.73333333e-03 3.80000000e-03 3.86666667e-03 3.93333333e-03
#  4.00000000e-03 4.06666667e-03 4.13333333e-03 4.20000000e-03
#  4.26666667e-03 4.33333333e-03 4.40000000e-03 4.46666667e-03
#  4.53333333e-03 4.60000000e-03 4.66666667e-03 4.73333333e-03
#  4.80000000e-03 4.86666667e-03 4.93333333e-03 5.00000000e-03
#  5.06666667e-03 5.13333333e-03 5.20000000e-03 5.26666667e-03
#  5.33333333e-03 5.40000000e-03 5.46666667e-03 5.53333333e-03
#  5.60000000e-03 5.66666667e-03 5.73333333e-03 5.80000000e-03
#  5.86666667e-03 5.93333333e-03]
# (90,)
# [ 0.11213203  0.56255622  0.73641387  0.78603871  0.99411676  0.75939299
#   0.58907141  0.44924535 -0.02730544 -0.1855723  -0.39196953 -0.67882711
#  -0.53666255 -0.56385013 -0.47434676 -0.11213203 -0.07447225  0.15535992
#   0.35522911  0.19930952  0.27983749  0.11627089 -0.19975132 -0.22218859
#  -0.51977    -0.64726096 -0.51459916 -0.60460527 -0.32792366 -0.01373721
#   0.11213203  0.56255622  0.73641387  0.78603871  0.99411676  0.75939299
#   0.58907141  0.44924535 -0.02730544 -0.1855723  -0.39196953 -0.67882711
#  -0.53666255 -0.56385013 -0.47434676 -0.11213203 -0.07447225  0.15535992
#   0.35522911  0.19930952  0.27983749  0.11627089 -0.19975132 -0.22218859
#  -0.51977    -0.64726096 -0.51459916 -0.60460527 -0.32792366 -0.01373721
#   0.11213203  0.56255622  0.73641387  0.78603871  0.99411676  0.75939299
#   0.58907141  0.44924535 -0.02730544 -0.1855723  -0.39196953 -0.67882711
#  -0.53666255 -0.56385013 -0.47434676 -0.11213203 -0.07447225  0.15535992
#   0.35522911  0.19930952  0.27983749  0.11627089 -0.19975132 -0.22218859
#  -0.51977    -0.64726096 -0.51459916 -0.60460527 -0.32792366 -0.01373721]
# (90,)
# señal x(t) cuantizada y digitalizada:

# %% [markdown]
# Se dispone de un sistema modelado como una "caja negra" (ver celdas de código). Su tarea es analizar y comprobar mediante simulaciones si el sistema cumple con las propiedades de linealidad e invariancia en el tiempo. En caso de que el sistema sea lineal e invariante con el tiempo, determine su respuesta al impulso y utilice esta respuesta para calcular la salida del sistema ante la siguiente señal:
#
# x[n]=sin[100πn]+sin[600πn]

# %%
# cargar sistema
FILEID = "1J9rhh0wWHZSBd8XmWGt1ZpCsMDuoUFmm"
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O P1_model.zip && rm -rf /tmp/cookies.txt
# !unzip -o P1_model.zip
# !dir

import numpy as np
import matplotlib.pyplot as plt
import joblib
from P1_model import system_
from scipy.signal import firwin, freqz, lfilter, filtfilt

#sistema pregunta 2
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs #frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo
signal_u = np.heaviside(t,1) # función heaviside
y_u = my_system.predict(signal_u)


# Visualización de las señales
fig, axs = plt.subplots(2,1)
axs[0].stem(t, signal_u, label='Señal de entrada')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid()
axs[1].stem(t,y_u, label='Señal salida')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()
# Out:
# --2024-12-12 01:18:18--  https://docs.google.com/uc?export=download&confirm=&id=1J9rhh0wWHZSBd8XmWGt1ZpCsMDuoUFmm
# Resolving docs.google.com (docs.google.com)... 142.250.101.139, 142.250.101.101, 142.250.101.113, ...
# Connecting to docs.google.com (docs.google.com)|142.250.101.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1J9rhh0wWHZSBd8XmWGt1ZpCsMDuoUFmm&export=download [following]
# --2024-12-12 01:18:18--  https://drive.usercontent.google.com/download?id=1J9rhh0wWHZSBd8XmWGt1ZpCsMDuoUFmm&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 732 [application/octet-stream]
# Saving to: ‘P1_model.zip’
#
# P1_model.zip        100%[===================>]     732  --.-KB/s    in 0s
#
# 2024-12-12 01:18:20 (40.4 MB/s) - ‘P1_model.zip’ saved [732/732]
#
# Archive:  P1_model.zip
#   inflating: P1_model/system_.py
# P1_model  P1_model.zip	sample_data

# %% [markdown]
# ##Solución

# %% [markdown]
# ## vamos a analizar y comprobar si el sistema mediante simulación cumple con las propiedades de linealidad e invarianza en el tiempo
# linealidad: recordemos que un sistema es lineal si satisface los principios de superposición y escalamiento.
#
# superposición: si una entrada X1(t) produce una salida Y1(t) y una entrada X2(t) produce una salida Y2(t) entonces la entrada X1(t) + X2(t) producira la salida Y1(t) +Y2(t)
#
# escalamiento: si se escala una entrada por un factor constante a la salida también se escala por el mismo factor S(a*x(t)) = a*S(x(t)), esto significa que el sistema responde de manera proporcional a la entrada

# %%
import numpy as np
import matplotlib.pyplot as plt
import joblib
from P1_model import system_
from scipy.signal import firwin, freqz, lfilter, filtfilt

#sistema pregunta 2
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs #frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo
signal_1 = np.cos(100 * np.pi * t) #señal de entrada 1
y_1 = my_system.predict(signal_1) #señal de salida 1

signal_2 = np.sin(150 * np.pi * t) #señal de entrada 2
y_2 = my_system.predict(signal_2) #señal  de salida 2


# Visualización de las señales de entrada 1 y 2 a la caja negra
fig, axs = plt.subplots(2,1)
axs[0].stem(t, signal_1, label='Señal de entrada 1')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid()
plt.tight_layout()

axs[1].stem(t, signal_2, label='Señal de entrada 2')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# dado que tenemos las 2 señales de entrada, podemos encontrar las 2 señales de salida del sistema

# %%
#vamos a gráficar las dos señales de salida del sistema (caja negra)
fig, axs = plt.subplots(2,1)
axs[0].stem(t,y_1, label='Señal de salida 1 sin escalamiento')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid()
plt.tight_layout()
axs[1].stem(t,y_2, label='Señal de salida 2 sin escalamiento')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# vamos a aplicar escalamiento a las 2 señales de salida y las vamos a gráficar

# %%
#vamos a simular la superposición de las 2 señales de entrada aplicado escalamiento a las dos señales de salida
a = 3 #escalar 1 arbitrario
b = 2 #escalar 2 arbitrario
y1 = a*y_1#escalamiento a señal de salida 1
y2 = b*y_2#escalamiento a señal de salida 2

fig, axs = plt.subplots(2,1)
axs[0].stem(t,y1, label='Señal de salida 1 con escalamiento')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid()
plt.tight_layout()
axs[1].stem(t,y2, label='Señal de salida 2 con escalamiento')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()

# %%
#aplicamos superposición junto con escalamiento a las dos señales de salida
y = y1 + y2 #combinación lineal de las dos señales de salida

fig, ax = plt.subplots(1,1)  # Aquí, ax se refiere al único subplot
ax.stem(t,y, label='Señal salida y(t)')
ax.set_xlabel('Tiempo (s)')
ax.set_ylabel('Amplitud')
ax.legend()
ax.grid()
plt.tight_layout()
plt.show()

# %%
#verificamos mediante simulación si el sistema es lineal g(t) = y(t)
import numpy as np
import matplotlib.pyplot as plt
from P1_model import system_

# Crear el sistema
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs  # Frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo
x1 = np.cos(100 * np.pi * t) # Calcular la salida para la señal x1(t)
y1 = my_system.predict(x1)

# Calcular la salida para la señal x2(t)
x2 = np.sin(150 * np.pi * t)
y2 = my_system.predict(x2)

# Definir la combinación lineal de las señales: α * x1 + β * x2
alpha = 2
beta = 3
x_combined = alpha * x1 + beta * x2

# Calcular la salida para la combinación lineal de las señales
y_combined = my_system.predict(x_combined)

# Calcular la combinación lineal de las salidas: α * y1 + β * y2
y_linear_combination = alpha * y1 + beta * y2

# Visualización de la verificación de linealidad
fig, axs = plt.subplots(1, 1, figsize=(5, 5))

# Gráfico de la salida para la combinación lineal
# The 'axs' object is not subscriptable when you have a single subplot.
# Use 'axs' directly instead of 'axs[0]'.
axs.plot(t, y_combined, label='Salida para la combinación lineal')
axs.plot(t, y_linear_combination, label='Combinación lineal de salidas', linestyle='--')
axs.set_xlabel('Tiempo (s)')
axs.set_ylabel('Amplitud')
axs.legend()
axs.set_title('Verificación de Linealidad')
axs.grid(True)

plt.tight_layout()
plt.show()

#sistema pregunta 2
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs #frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo
signal_1 = np.cos(100 * np.pi * t) #señal de entrada 1
y_1 = my_system.predict(signal_1) #señal de salida 1

signal_2 = np.sin(150 * np.pi * t) #señal de entrada 2
y_2 = my_system.predict(signal_2) #señal  de salida 2

# %% [markdown]
# ##Ahora vamos a determinar si el sistema es invariante en el tiempo##
#
# Un sistema es invariante en el tiempo si su comportamiento no cambia en el tiempo, es decir S(x(t-to) = y(t-to), esto implica que las propiedades del sistema no dependen del instante en que se aplica la entrada.

# %%
tau = float(input("Hola, podrías ingresar un valor entre -0.005 y 0.015 para visualizar el desplazamiento de la función: "))
my_system.create_()
fs = my_system.fs #frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo
signal_u = np.heaviside(t-tau,1) # función heaviside desplazada un valor tau asignado por el usuario
y_u = my_system.predict(signal_u)


# Visualización de las señales
fig, axs = plt.subplots(2,1)
axs[0].stem(t, signal_u, label='Señal de entrada')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid()
axs[1].stem(t,y_u, label='Señal salida')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid()
plt.tight_layout()
plt.show()
# Out:
# Hola, podrías ingresar un valor entre -0.005 y 0.015 para visualizar el desplazamiento de la función: 0.010

# %% [markdown]
# Dado que se  puede verificar que el sistema es invariante en el tiempo, podemos calcular la respuesta al impulso del sistema

# %%
import numpy as np
import matplotlib.pyplot as plt
from P1_model import system_

# Crear el sistema
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs  # Frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo

# Generar el impulso discreto (Kronecker delta)
impulse = np.zeros_like(t)
impulse[len(t)//2] = 1  # Establecer el valor en n=0 (en el centro)

# Aplicar la señal impulso al sistema
y_impulse = my_system.predict(impulse)

# Visualización de las señales
fig, axs = plt.subplots(2, 1, figsize=(5, 5))

# Señal de impulso
axs[0].stem(t, impulse, label='Señal de entrada (impulso)', linefmt='b-', markerfmt='bo')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid(True)
axs[0].set_title('Respuesta al Impulso: Señal de Entrada')

# Respuesta del sistema (salida)
axs[1].stem(t, y_impulse, label='Respuesta al impulso (salida)', linefmt='g-', markerfmt='go')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid(True)
axs[1].set_title('Respuesta al Impulso del Sistema')

plt.tight_layout()
plt.show()

# %% [markdown]
# ahora vamos a calcular la salida del sistema ante la siguiente señal: x[n]=sin[100πn]+sin[600πn] en tiempo discreto

# %%
import numpy as np
import matplotlib.pyplot as plt
from P1_model import system_

# Crear el sistema
my_system = system_.My_System()
my_system.create_()
fs = my_system.fs  # Frecuencia de muestreo
t = np.arange(-0.01, 0.02, 1/fs)  # Tiempo

# Generar el impulso discreto (Kronecker delta)
impulse = np.zeros_like(t)
impulse[len(t)//2] = 1  # Establecer el valor en n=0 (en el centro)

# Aplicar la señal impulso al sistema
y_impulse = my_system.predict(impulse)

# Definir la señal de entrada: x[n] = sin(100πn) + sin(600πn)
x_n = np.sin(100 * np.pi * t) + np.sin(600 * np.pi * t)

# Convolución entre la señal de entrada x[n] y la respuesta al impulso h[n]
y_n = np.convolve(x_n, y_impulse, mode='same')

# Visualización de las señales
fig, axs = plt.subplots(2, 1, figsize=(5, 5))

# Señal de entrada x[n]
axs[0].stem(t, x_n, label='Señal de entrada x[n]', linefmt='b-', markerfmt='bo')
axs[0].set_xlabel('Tiempo (s)')
axs[0].set_ylabel('Amplitud')
axs[0].legend()
axs[0].grid(True)
axs[0].set_title('Señal de Entrada: x[n] = sin(100πn) + sin(600πn)')

# Salida del sistema y[n] = x[n] * h[n]
axs[1].stem(t, y_n, label='Salida del sistema y[n]', linefmt='g-', markerfmt='go')
axs[1].set_xlabel('Tiempo (s)')
axs[1].set_ylabel('Amplitud')
axs[1].legend()
axs[1].grid(True)
axs[1].set_title('Salida del Sistema: y[n] = x[n] * h[n]')

plt.tight_layout()
plt.show()
